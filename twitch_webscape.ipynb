# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
chrome_options = Options()
chrome_options.add_argument('--headless')
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://streamscharts.com/top-channels?sortBy=peak_viewers")
driver.implicitly_wait(10)
html = driver.page_source
driver.quit()

# %%
webpage = bs(html, 'html.parser')
print(webpage.prettify())
# Out:
# <html class="overflow-x-hidden dark filter-right smooth_scroll" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="fiLIDRu8T6Rw4IAPLH3iARW4YKjrCyhD96mudJkC" name="csrf-token"/>
#   <link href="https://static.streamscharts.com/favicon/sc-favicon.png" rel="apple-touch-icon" sizes="128x128"/>
#   <link href="https://static.streamscharts.com/favicon/sc-favicon.png" rel="icon" sizes="128x128" type="image/png"/>
#   <meta content="#050509" name="theme-color"/>
#   <title>
#    Streamers With the Highest Viewers · Streams Charts
#   </title>
#   <meta content="Learn statistics about Twitch, Trovo, NimoTV, Bigo LIVE, Nonolive, AfreecaTV, Mildom, Kick influencers with most concurrent viewers ➥ Detail stats about streamers with the highest record number of viewers - Viewers, Followers and more!" name="description"/>
#   <meta content="Streamers With the Highest Viewers · Streams Charts" property="og:title"/>
#   <meta content="Learn statistics about Twitch, Trovo, NimoTV, Bigo LIVE, Nonolive, AfreecaTV, Mildom, Kick influencers with most concurrent viewers ➥ Detail stats about streamers with the highest record number of viewers - Viewers, Followers and more!" property="og:description"/>
#   <meta content="https://static.streamscharts.com/img/meta/top-channels-peak_fb.jpg" property="og:image"/>
#   <meta content="https://static.streamscharts.com/img/meta/top-channels-peak_vk.jpg" property="og:image"/>
#   <meta content="https://static.streamscharts.com/img/meta/top-channels-peak_twitter.jpg" name="twitter:image"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Streamers With the Highest Viewers · Streams Charts" name="twitter:title"/>
#   <meta content="Learn statistics about Twitch, Trovo, NimoTV, Bigo LIVE, Nonolive, AfreecaTV, Mildom, Kick influencers with most concurrent viewers ➥ Detail stats about streamers with the highest record number of viewers - Viewers, Followers and more!" name="twitter:description"/>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.beta.min.js">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-EWRXQ5LP6S&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.beta.min.js">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.beta.min.js">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.beta.min.js">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.beta.min.js">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/565372958261513?v=2.9.138&amp;r=stable&amp;domain=streamscharts.com">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-55XTCTG">
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"WebPage","name":"Streamers With the Highest Viewers · Streams Charts","description":"Learn statistics about Twitch, Trovo, NimoTV, Bigo LIVE, Nonolive, AfreecaTV, Mildom, Kick influencers with most concurrent viewers ➥ Detail stats about streamers with the highest record number of viewers - Viewers, Followers and more!","image":["https://static.streamscharts.com/img/meta/top-channels-peak_fb.jpg","https://static.streamscharts.com/img/meta/top-channels-peak_vk.jpg"]}
#   </script>
#   <link href="https://streamscharts.com/top-channels?sortBy=peak_viewers" rel="canonical"/>
#   <link href="https://streamscharts.com/feed" rel="alternate" title="Streams Charts Feed" type="application/rss+xml"/>
#   <link href="https://static.streamscharts.com/css/app-sc.css?v=2" rel="stylesheet"/>
#   <script type="application/ld+json">
#    {
#           "@context": "https://schema.org",
#           "@type": "WebSite",
#           "url": "https://streamscharts.com",
#           "potentialAction": {
#             "@type": "SearchAction",
#             "target": "https://streamscharts.com/channels/search?query={search_term_string}",
#             "query-input": "required name=search_term_string"
#           }
#         }
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         var dl = {
#             'data-current-uri': 'top-channels',
#                                 };
#                 dataLayer.push(dl);
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-55XTCTG');
#   </script>
#   <meta content="" http-equiv="origin-trial"/>
#  </head>
#  <body class="min-h-screen antialiased font-proxima tabular-nums bg-body text-default">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-55XTCTG" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div :class="{ 'bg-green': style == 'success', 'bg-red-700': style == 'danger' }" class="bg-green" style="display: none;" x-data='{"show":true,"style":"success","message":null}' x-init="
#                 document.addEventListener('banner-message', event =&gt; {
#                     style = event.detail.style;
#                     message = event.detail.message;
#                     show = true;
#                 });
#             " x-show="show &amp;&amp; message">
#    <div class="max-w-screen-2xl mx-auto py-2 px-3 sm:px-6">
#     <div class="flex items-center justify-between flex-wrap">
#      <div class="w-0 flex-1 flex items-center min-w-0">
#       <span :class="{ 'bg-green-dark': style == 'success', 'bg-red-600': style == 'danger' }" class="flex p-2 rounded-lg bg-green-dark">
#        <svg class="!h-5 !w-5 text-white" fill="none" stroke="currentColor" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M9 12l2 2 4-4m6 2a9 9 0 11-18 0 9 9 0 0118 0z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
#         </path>
#        </svg>
#       </span>
#       <p class="ml-3 font-medium text-sm text-white truncate" x-text="message">
#       </p>
#      </div>
#      <div class="flex-shrink-0 sm:ml-3">
#       <button :class="{ 'hover:bg-green-dark focus:bg-green-dark': style == 'success', 'hover:bg-red-600 focus:bg-red-600': style == 'danger' }" aria-label="Dismiss" class="-mr-1 flex p-2 rounded-md focus:outline-none sm:-mr-2 transition ease-in-out duration-150 hover:bg-green-dark focus:bg-green-dark" type="button" x-on:click="show = false">
#        <svg class="!h-5 !w-5 text-white" fill="none" stroke="currentColor" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M6 18L18 6M6 6l12 12" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
#         </path>
#        </svg>
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <nav :style="`--x: ${x}px; --width: ${width}px`" aria-label="Site navigation" class="menu" data-menuid="main-menu-other-links" style="--x: 16px; --width: 87px" x-data="{
#         menu_open: false,
#         profile_open: false,
#         changelogs_open: false,
#         activeChangelogs: 1,
#         notifications_open: false,
#         activeNotifications: 1,
#         menu_states: {},
#         x: 0,
#         width: 0,
#         lastScroll: 0,
#         initNavigation() {
#             if (this.$refs.current) {
#                 const current = this.$refs.current;
#                 this.x = current.parentNode.offsetLeft + 16;
#                 const computedStyle = getComputedStyle(current);
#                 this.width = current.clientWidth - parseFloat(computedStyle.paddingLeft) - parseFloat(computedStyle.paddingRight);
#             }
#             const menu = this.$el;
#             const menuHeight = menu.clientHeight;
#             let lastScroll = window.pageYOffset || document.documentElement.scrollTop;
#             window.addEventListener('scroll', () =&gt; {
#                 let currentScroll = window.pageYOffset || document.documentElement.scrollTop;
#                 if (currentScroll &gt; lastScroll &amp;&amp; currentScroll &gt; menuHeight) {
#                     this.menu_open = false;
#                     this.profile_open = false;
#                     this.changelogs_open = false;
#                     this.notifications_open = false;
#                     menu.classList.add('menu-hidden');
#                 } else {
#                     menu.classList.remove('menu-hidden');
#                 }
#                 lastScroll = currentScroll;
#             });
#         },
#         navigate(target) {
#             if (document.querySelector('.menu-click') &amp;&amp; target.closest('li').classList.contains('l_a')) {
#                 return
#             }
#             target = target.closest('.l_a') &amp;&amp; target.closest('.l_a').querySelector('a') ? target.closest('.l_a').querySelector('a') : target
#             this.x = target.parentNode.offsetLeft + 16;
#             const computedStyle = getComputedStyle(target);
#             this.width = target.clientWidth - parseFloat(computedStyle.paddingLeft) - parseFloat(computedStyle.paddingRight);
#         }
#     }" x-init="initNavigation()" x-on:click.away="menu_open = false; profile_open = false; changelogs_open = false; notifications_open = false;">
#    <div class="menu-container">
#     <div class="menu-logo sm-max:hidden" data-menuid="main-menu-logo">
#      <a class="text-default" href="/" title="Streams Charts home page">
#       <img alt="Streams Charts" class="flex-shrink-0 w-9 h-9 xl:hidden min-w-9" src="https://static.streamscharts.com/img/sc-symbol.svg"/>
#       <div class="hidden js-logo xl:block">
#        <img alt="Streams Charts logo" class="hidden-dark max-w-none" decode="async" height="39" loading="lazy" src="https://static.streamscharts.com/img/logos/streamscharts-dark.svg" width="115"/>
#        <img alt="Streams Charts logo" class="hidden-light max-w-none" decode="async" height="39" loading="lazy" src="https://static.streamscharts.com/img/logos/streamscharts-light.svg" width="115"/>
#       </div>
#      </a>
#     </div>
#     <div class="menu-items_container">
#      <button :aria-label="menu_open ? 'Close site navigation' : 'Open site navigation'" @click="menu_open = !menu_open; profile_open = false; changelogs_open = false; notifications_open = false;" aria-label="Open site navigation" class="menu-toggle" data-menuid="main-menu-mobile-toogle">
#       <span x-show="!menu_open">
#        <svg class="w-4 h-4 fill-current !w-5 !h-5" name="menu-line" title="menu-line">
#         <use class="fill-current" href="/sprite.svg?v=1.11#icon-menu-line">
#         </use>
#        </svg>
#       </span>
#       <span class="x-cloak-hidden" style="display: none;" x-show="menu_open">
#        <svg class="w-4 h-4 fill-current !w-5 !h-5" name="close" title="close">
#         <use class="fill-current" href="/sprite.svg?v=1.11#icon-close">
#         </use>
#        </svg>
#       </span>
#      </button>
#      <div class="ml-6 menu-logo md:hidden" data-menuid="main-menu-logo">
#       <a class="text-default" href="/" title="Streams Charts home page">
#        <img alt="Streams Charts" class="flex-shrink-0 w-9 h-9 xl:hidden min-w-9" src="https://static.streamscharts.com/img/sc-symbol.svg"/>
#        <div class="hidden js-logo xl:block">
#         <img alt="Streams Charts logo" class="hidden-dark max-w-none" decode="async" height="39" loading="lazy" src="https://static.streamscharts.com/img/logos/streamscharts-dark.svg" width="115"/>
#         <img alt="Streams Charts logo" class="hidden-light max-w-none" decode="async" height="39" loading="lazy" src="https://static.streamscharts.com/img/logos/streamscharts-light.svg" width="115"/>
#        </div>
#       </a>
#      </div>
#      <div :class="{
#                     'hid': !menu_open,
#                 }" class="menu-items_list x-cloak-xl:flex hid">
#       <ul class="menu-items_ul xl:navigation_line">
#        <li class="i l_a" data-menuid="main-menu-1lvl">
#         <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview">
#          Platforms
#         </a>
#         <input class="hidden css_menu-checkbox" id="Platforms-check" name="Platforms-check" type="checkbox"/>
#         <label aria-label="Open submenu" class="menu-link-chevron" for="Platforms-check">
#          <img class="w-4 h-4" src="https://static.streamscharts.com/icons/chevron-down.svg"/>
#         </label>
#         <ul class="menu-link-dropdown">
#          <div class="grid grid-cols-12 sm-max:pb-2.5">
#           <ul class="col-span-6 border-r border-header_secondary">
#            <li class="menu-link-label">
#             Platform overview
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview">
#              <img alt="Twitch" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/twitch-icon.svg"/>
#              Twitch
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=youtube">
#              <img alt="Youtube stats" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/youtube-icon.svg"/>
#              Youtube
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=trovo">
#              <img alt="Trovo stats" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/trovo-icon.svg"/>
#              Trovo
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=kick">
#              <img alt="Kick stats" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/kick-icon.svg"/>
#              Kick
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=nimo">
#              <img alt="Nimo" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/nimo-icon.svg"/>
#              NimoTV
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=bigo">
#              <img alt="Bigo live stats" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/bigo-icon.svg"/>
#              Bigo Live
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=nonolive">
#              <img alt="Nanolive" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/nonolive-icon.svg"/>
#              Nonolive
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=afreecatv">
#              <img alt="AfreecaTV" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/afreecatv-icon.svg"/>
#              AfreecaTV
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=mildom">
#              <img alt="Mildom" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/mildom-icon.svg"/>
#              Mildom
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview?platform=rumble">
#              <img alt="Rumble stats" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/rumble-icon.svg"/>
#              Rumble
#             </a>
#            </li>
#           </ul>
#           <ul class="col-span-6 pl-1 sm-max:pl-2">
#            <li class="menu-link-label">
#             Partnership stats
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/overview/partners">
#              Twitch Partners &amp; Affiliates
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Platforms analytics
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/compare-streamers">
#              Compare Streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/titles-checker">
#              Streams Titles Checker
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Languages
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/languages/english">
#              English
#              <span class="flex h-4 px-1 ml-3 font-bold rounded uppercase text-xxs text-green place-content-center bg-opacity-10 bg-green relative" style="top: 2px;">
#               NEW
#              </span>
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/languages/spanish">
#              Spanish
#              <span class="flex h-4 px-1 ml-3 font-bold rounded uppercase text-xxs text-green place-content-center bg-opacity-10 bg-green relative" style="top: 2px;">
#               NEW
#              </span>
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/languages/portuguese">
#              Portuguese
#              <span class="flex h-4 px-1 ml-3 font-bold rounded uppercase text-xxs text-green place-content-center bg-opacity-10 bg-green relative" style="top: 2px;">
#               NEW
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </ul>
#        </li>
#        <li class="i l_a" data-menuid="main-menu-1lvl">
#         <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels">
#          Channels
#         </a>
#         <input class="hidden css_menu-checkbox" id="Channels-check" name="Channels-check" type="checkbox"/>
#         <label aria-label="Open submenu" class="menu-link-chevron" for="Channels-check">
#          <img class="w-4 h-4" src="https://static.streamscharts.com/icons/chevron-down.svg"/>
#         </label>
#         <div class="menu-link-dropdown">
#          <div class="grid grid-cols-12 sm-max:pb-2.5">
#           <ul class="col-span-6 border-r border-header_secondary">
#            <li class="menu-link-label">
#             Group by
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels">
#              Channels (streamers)
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" data-tippy-content="List of top streams" href="https://streamscharts.com/streams" style="cursor: pointer;">
#              Streams (broadcasts)
#              <svg class="w-4 h-4 fill-current text-secondary opacity-75 ml-2 !w-3.5 !h-3.5" name="information" title="information">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#               </use>
#              </svg>
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" data-tippy-content="List of top twitch.tv teams and their stats&lt;br&gt;&lt;span class='opacity-50'&gt;G FUEL, Loaded, FREAK etc.&lt;/span&gt;" href="https://streamscharts.com/teams" style="cursor: pointer;">
#              Twitch Teams (squads)
#              <svg class="w-4 h-4 fill-current text-secondary opacity-75 ml-2 !w-3.5 !h-3.5" name="information" title="information">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#               </use>
#              </svg>
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" data-tippy-content="Your personalized lists of channels.&lt;br&gt;&lt;span class='opacity-50'&gt; + Esports, HLTV TOP20, Speedrunners etc.&lt;/span&gt;" href="https://streamscharts.com/lists" style="cursor: pointer;">
#              User's Lists (personal lists)
#              <svg class="w-4 h-4 fill-current text-secondary opacity-75 ml-2 !w-3.5 !h-3.5" name="information" title="information">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#               </use>
#              </svg>
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Filter by platform
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels">
#              All platforms
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?platform=twitch">
#              Twitch streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?platform=trovo">
#              Trovo streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?platform=kick">
#              Kick streamers
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Sort by
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels">
#              Hours Watched
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?sortBy=peak_viewers">
#              Peak Viewers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?sortBy=avg_concurrent_viewers">
#              Average Viewers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?sortBy=followers_gain">
#              Followers Gain
#             </a>
#            </li>
#           </ul>
#           <ul class="col-span-6 pl-1 sm-max:pl-2">
#            <li class="menu-link-label">
#             Filter by popular filters
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?category=esports">
#              Esports channels
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?vtuber=all">
#              VTubers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?category=irl">
#              IRL streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              Esports Twitch Teams
#             </span>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?sponsorship=only_sponsors">
#              Seeking sponsor streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?type=female">
#              Female streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?game=just-chatting">
#              Just Chatting streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?lang=en">
#              English-speaking streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?partner=only_partners">
#              Partnered streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              100-500 AVG Viewers
#             </span>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              Fast-growing streamers
#             </span>
#            </li>
#            <li class="flex items-center pt-4 menu-link-label" data-tippy-content="Based on user's contributions">
#             Filter by country
#             <svg class="w-4 h-4 fill-current text-secondary ml-2 inline-block w-3.5 h-3.5 align-text-bottom" name="information" title="information">
#              <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#              </use>
#             </svg>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              Streamers from Brazil
#             </span>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              Streamers from USA
#             </span>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              Streamers from Spain
#             </span>
#            </li>
#            <li class="flex items-center pt-4 menu-link-label" data-tippy-content="Based on user's contributions">
#             Filter by channel type
#             <svg class="w-4 h-4 fill-current text-secondary ml-2 inline-block w-3.5 h-3.5 align-text-bottom" name="information" title="information">
#              <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#              </use>
#             </svg>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels?type=female">
#              Female
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              Male
#             </span>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl" data-tippy-content="For PRO users only">
#             <span class="cursor-not-allowed menu-link hover:text-secondary">
#              <svg class="w-4 h-4 fill-current !w-3.5 flex-shrink-0 !h-3.5 mr-2 opacity-75" name="lock-fill" title="lock-fill">
#               <use class="fill-current" href="/sprite.svg?v=1.11#icon-lock-fill">
#               </use>
#              </svg>
#              Organization
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </li>
#        <li class="i active l_a" data-menuid="main-menu-1lvl">
#         <a @click="navigate($event.target)" class="lg-max:left_navigation_line x-cloak-lg:navigation_active" href="https://streamscharts.com/top-channels" x-ref="current">
#          Leaderboards
#         </a>
#         <input class="hidden css_menu-checkbox" id="Leaderboards-check" name="Leaderboards-check" type="checkbox"/>
#         <label aria-label="Open submenu" class="menu-link-chevron" for="Leaderboards-check">
#          <img class="w-4 h-4" src="https://static.streamscharts.com/icons/chevron-down.svg"/>
#         </label>
#         <ul class="menu-link-dropdown">
#          <li class="menu-link-label">
#           Top channels
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-live-channels">
#            Top 50 LIVE channels by viewers
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/subscribers">
#            Top Twitch streamers by active subs
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/subscribers?sortBy=income">
#            Top Twitch streamers by income from subs
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/bits">
#            Top Twitch streamers by bits count
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/bits?sortBy=income">
#            Top Twitch streamers by income from bits
#           </a>
#          </li>
#          <li class="mt-4 menu-link-label">
#           Top Channels, all-time
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-channels">
#            Top 50 Most Followed channels
#           </a>
#          </li>
#          <li class="i active" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-channels?sortBy=peak_viewers">
#            Top 50 streamers by Peak Viewers
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-channels?type=female">
#            Top 50 Most Followed Female streamers
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-channels?sortBy=peak_viewers&amp;type=female">
#            Top 50 Female streamers by Peak Viewers
#           </a>
#          </li>
#          <li class="mt-4 menu-link-label">
#           Top Games, all-time
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-games">
#            Top 50 games by Peak Viewers
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-games?sortBy=peak_channels">
#            Top 50 games by Peak Channels
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="i l_a" data-menuid="main-menu-1lvl">
#         <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games">
#          Games
#         </a>
#         <input class="hidden css_menu-checkbox" id="Games-check" name="Games-check" type="checkbox"/>
#         <label aria-label="Open submenu" class="menu-link-chevron" for="Games-check">
#          <img class="w-4 h-4" src="https://static.streamscharts.com/icons/chevron-down.svg"/>
#         </label>
#         <ul class="menu-link-dropdown">
#          <li class="menu-link-label">
#           Group by
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games">
#            All games
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/publishers">
#            Publishers
#           </a>
#          </li>
#          <li class="pt-4 menu-link-label">
#           Sort by
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games">
#            Hours Watched
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games?sortBy=peak_viewers">
#            Peak Viewers
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games?sortBy=peak_channels">
#            Peak Channels
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games?sortBy=viewers_per_channel">
#            Viewers per Channel rate
#           </a>
#          </li>
#          <li class="pt-4 menu-link-label">
#           Filter by genres
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games?genre=Action">
#            Action
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games?genre=FPS">
#            FPS
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games?genre=MOBA">
#            MOBA
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/games?genre=Open%2520World">
#            Open World
#           </a>
#          </li>
#          <li class="mt-4 menu-link-label">
#           Top Games, all-time
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-games">
#            Top 50 games by Peak Viewers
#           </a>
#          </li>
#          <li class="i" data-menuid="main-menu-2lvl">
#           <a @click="navigate($event.target)" class="" href="https://streamscharts.com/top-games?sortBy=peak_channels">
#            Top 50 games by Peak Channels
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="i l_a" data-menuid="main-menu-1lvl">
#         <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips">
#          Clips
#         </a>
#         <input class="hidden css_menu-checkbox" id="Clips-check" name="Clips-check" type="checkbox"/>
#         <label aria-label="Open submenu" class="menu-link-chevron" for="Clips-check">
#          <img class="w-4 h-4" src="https://static.streamscharts.com/icons/chevron-down.svg"/>
#         </label>
#         <div class="menu-link-dropdown">
#          <div class="grid grid-cols-12 sm-max:pb-2.5">
#           <ul class="col-span-6 border-r border-header_secondary">
#            <li class="menu-link-label">
#             Filter by period
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?time=today">
#              Today
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips">
#              Last 7 days
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?time=30-days">
#              Last 30 days
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?time=all-time">
#              All time
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Filter by top categories
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?game=just-chatting">
#              Just Chatting
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?game=grand-theft-auto-v">
#              GTA V
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?game=minecraft">
#              Minecraft
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?game=league-of-legends">
#              League of Legends
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?game=fortnite">
#              Fortnite
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?game=counter-strike-global-offensive">
#              CS:GO
#             </a>
#            </li>
#           </ul>
#           <ul class="col-span-6 pl-1 sm-max:pl-2">
#            <li class="menu-link-label">
#             Filter by top streamers
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels/xqc/clips">
#              xQc
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels/ibai/clips">
#              ibai
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels/auronplay/clips">
#              auronplay
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels/amouranth/clips">
#              Amouranth
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/channels/loltyler1/clips">
#              loltyler1
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Tools
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips/downloader">
#              Clip Downloader
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips/feed">
#              Clips Feed
#              <span class="ml-3 font-normal uppercase text-primary text-xxs md:line-clamp-1">
#               new
#              </span>
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Filter by content
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?vtuber=all">
#              VTubers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?category=irl">
#              IRL
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/clips?category=esports">
#              Esports
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </li>
#        <li class="i l_a" data-menuid="main-menu-1lvl">
#         <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/chat-analyzer">
#          Twitch Tools
#         </a>
#         <input class="hidden css_menu-checkbox" id="Twitch Tools -check" name="Twitch Tools -check" type="checkbox"/>
#         <label aria-label="Open submenu" class="menu-link-chevron" for="Twitch Tools -check">
#          <img class="w-4 h-4" src="https://static.streamscharts.com/icons/chevron-down.svg"/>
#         </label>
#         <ul class="menu-link-dropdown">
#          <div class="grid grid-cols-12 sm-max:pb-2.5">
#           <ul class="col-span-6 border-r border-header_secondary">
#            <li class="menu-link-label">
#             Guessing game
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/guess-streamers">
#              <img alt="guess logo" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/guess-streamers/logo.svg"/>
#              Whose Avatar is That?
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Streams Charts special
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://bit.ly/3AyUnQl" rel="noindex nofollow" target="_blank">
#              <img alt="SC chrome extension" class="w-4 h-4 mr-2" decoding="async" loading="lazy" src="https://static.streamscharts.com/img/logos/chrome-icon.svg"/>
#              Twitch Stats Chrome Extension
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Channel analytics
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/raid-finder">
#              Raid finder
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/followage">
#              Followage
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/compare-streamers">
#              Compare Streamers
#             </a>
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/convert-username">
#              Convert Username to ID
#             </a>
#            </li>
#            <li class="pt-4 menu-link-label">
#             Game analytics
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/trends/games">
#              Top growing games
#             </a>
#            </li>
#           </ul>
#           <ul class="col-span-6 pl-1 sm-max:pl-2">
#            <li class="menu-link-label">
#             Twitch activity
#            </li>
#            <li class="i" data-menuid="main-menu-2lvl">
#             <a @click="navigate($event.target)" class="" href="https://streamscharts.com/tools/chat-analyzer">
#              Brand Chat Analyzer
# ...
#                     minValue: Number(elem.dataset.mincurrent),
#                     maxValue: Number(elem.dataset.maxcurrent),
#                     minValuePlaceholder: null,
#                     maxValuePlaceholder: null,
#                     min: Number(elem.dataset.min),
#                     max: Number(elem.dataset.max),
#                     minthumb: 0,
#                     maxthumb: 0,
#                     active: false,
#                     filterID: null,
#                     init: function(){
#                         this.mintrigger(true);
#                         this.maxtrigger(true);
#                         this.setValues();
#                         this.filterID = this.$el.dataset.filterid;
#                     },
#                     changeActivity(event, $dispatch){
#                         this.active = true;
#                         window.sideFilters[this.filterID] = `${this.minValue}-${this.maxValue}`;
#                         // $dispatch('toggle-sidebar-filter');
#                         $dispatch('toggle-sidebar-filter', {
#                             target: event.target.closest('.filter-row').querySelector('.apply_point')
#                         });
#                     },
#                     mintrigger(init = false) {
#                         this.validation();
#                         if (this.minValue > this.maxValue) {
#                             this.maxValue = this.minValue;
#                             this.maxthumb = 100 - (((this.maxValue - this.min) / (this.max - this.min)) * 100);
#                         }
#                         // this.minValue = Math.min(this.minValue, this.maxValue);
#                         this.minthumb = ((this.minValue - this.min) / (this.max - this.min)) * 100;
#                     },
#                     maxtrigger(init = false) {
#                         // if (!init) {
#                         this.validation();
#                         if (this.maxValue < this.minValue) {
#                             this.minValue = this.maxValue;
#                             this.minthumb = ((this.minValue - this.min) / (this.max - this.min)) * 100;
#                         }
#                         // this.maxValue = Math.max(this.maxValue, this.minValue);
#                         this.maxthumb = 100 - (((this.maxValue - this.min) / (this.max - this.min)) * 100);
#                     // } else {
#                     //     this.maxthumb = 0;
#                     // }
#                     },
#                     validation() {
#                         if (/^\d*$/.test(this.minValue)) {
#                             if (this.minValue > this.max) {
#                                 this.minValue = this.max;
#                             }
#                             if (this.minValue < this.min) {
#                                 this.minValue = this.min;
#                             }
#                         } else {
#                             this.minValue = 0;
#                         }
#                         if (/^\d*$/.test(this.maxValue)) {
#                             if (this.maxValue > this.max) {
#                                 this.maxValue = this.max;
#                             }
#                             if (this.maxValue < this.min) {
#                                 this.maxValue = this.min;
#                             }
#                         } else {
#                             this.maxValue = this.max;
#                         }
#                     },
#                     setValues(){
#                         this.minValue = (this.minValue === this.min ? null : this.minValue);
#                         this.maxValue = (this.maxValue === this.max ? null : this.maxValue);
#                     },
#                     isSelected(min, max){
#                         return this.minValue === min && this.maxValue === max;
#                     },
#                     isCurrent(current, filterID){
#                         return window.sideFilters[filterID] && current;
#                     },
#                     // Only for combine filters
#                     toggleFilter: function(filterID, multiselect, isInclude, $dispatch){
#                         // const input = document.getElementById(inputId);
#                         // if (!input && input.checked === undefined) return;
#
#                         const key = `${this.minValue}-${this.maxValue}`;
#                         const value = isInclude ? key : `!${key}`;
#                         // const filterID = input.dataset.filterid;
#                         // const multiselect = input.dataset.multiselect === 'true';
#
#                         this.active = true;
#
#                         if (!window.sideFilters[filterID] && multiselect){
#                             window.sideFilters[filterID] = [];
#                         }
#
#                         if (!multiselect) {
#                             if (window.sideFilters[filterID] == value){
#                                 window.sideFilters[filterID] = null;
#                                 this.minValue = 0;
#                                 this.maxValue = 0;
#                                 // input.checked = false;
#                             }else {
#                                 window.sideFilters[filterID] = value;
#                                 // input.checked = true;
#                             }
#                             $dispatch('toggle-sidebar-filter', {
#                                 target: event.target.closest('.filter-row').querySelector('.apply_point')
#                             });
#                             return;
#                         }
#                     },
#                 }
#             }
#   </script>
#   <script>
#    let platforms = JSON.stringify(["afreecatv","bigo","nimo","nonolive","trovo","twitch"]);
#
#             function sidebarFilter() {
#                 return {
#                     top: 0,
#                     filters_open: false,
#                     pro_filters_open: false,
#                     filterUrl: '',
#                     applying: false,
#                     initFilters: {},
#                     diffPlus: 0,
#                     diffMinus: 0,
#                     isLoading: false,
#                     ignoreSort: false,
#                     initFiltersData: function(){
#                         // get nonDefaultFilters from base-table-view
#                         const data = JSON.parse(this.$el.dataset.active_filters);
#                         for (const filterKey in data) {
#                             let filterValue = data[filterKey].map(item => item.value || item );
#                             window.sideFilters[filterKey] = [ ...filterValue ];
#                             this.initFilters[filterKey] = [ ...filterValue ];
#                         }
#                     },
#                     onApply: function(e){
#                         if (window.innerWidth >= 1320){
#                             this.top = e.detail.target.getBoundingClientRect().top - this.$el.getBoundingClientRect().top - 10 + 'px';
#                         }else{
#                             this.top = e.detail.target.getBoundingClientRect().top + this.$refs['scroll-body'].scrollTop - 40 + 'px';
#                         }
#                         this.filterUrl = window.location.origin + window.location.pathname + '?';
#
#                         const urlParams = new URL(window.location.href);
#                         let ignorePlatformApply = false;
#                         let countAvailablePlatforms = JSON.parse(platforms).length;
#                         for (const filterKey in window.sideFilters) {
#                             let filterValue = window.sideFilters[filterKey];
#                             // Ignore apply when empty checkbox and url empty
#                             if (Array.isArray(filterValue) && filterValue.sort().length === 0 && !urlParams.searchParams.get('platform')) {
#                                 ignorePlatformApply = true;
#                             }
#
#                             // When choose all platforms - ignore
#                             if (filterKey === 'platform' && JSON.stringify(filterValue.sort()) === platforms) {
#                                 // Ignore add platforms for filter
#                             } else {
#                                 if (Array.isArray(filterValue)) filterValue = filterValue.join(',');
#                                 if (filterValue) this.filterUrl += `${filterKey}=${filterValue}&`;
#                             }
#
#                             // Crutch for growing streamers
#                             if (filterKey === 'growing_streamers') {
#                                 if (['followers_gain_100k', 'followers_gain_1m', 'followers_gain_100', 'fg_per_hour_100'].includes(filterValue)) {
#                                     this.filterUrl += `sortBy=followers_gain&`;
#                                 } else if (['avg_viewers_100', 'avg_viewers_100_1k'].includes(filterValue)) {
#                                     this.filterUrl += `sortBy=avg_concurrent_viewers&`;
#                                 } else if (['hours_watched_100', 'hours_watched_100_10k'].includes(filterValue)) {
#                                     this.filterUrl += `sortBy=hours_watched&`;
#                                 }
#                                 this.ignoreSort = true;
#                             }
#                         }
#
#                         const urlSearchParams = new URLSearchParams(window.location.search);
#                         const params = Object.fromEntries(urlSearchParams.entries());
#
#                         if(params.sortBy && !this.ignoreSort){
#                             this.filterUrl += `sortBy=${params.sortBy}&`
#                         }
#
#                         if(params.search){
#                             this.filterUrl += `search=${params.search}&`
#                         }
#
#                         // Crutch for tagsSearch[0] && tagsSearch[1] && ...
#                         // JS don't understand array in query
#                         let i = 0;
#                         let notFound = true;
#                         do {
#                             let tagsSearch = 'tagsSearch[' + i + ']';
#                             if (params[tagsSearch]) {
#                                 notFound = false;
#                                 let current = params[tagsSearch];
#                                 this.filterUrl += `${tagsSearch}=${current}&`
#                             } else {
#                                 notFound = true;
#                             }
#                             i = i + 1;
#                         } while (!notFound);
#
#                         this.filterUrl = this.filterUrl.slice(0, -1);
#
#                         this.applying = false;
#
#                         let diffPlus = 0, diffMinus = 0;
#                         for (const key in this.initFilters) {
#                             if (Object.hasOwnProperty.call(window.sideFilters, key)) {
#                                 const initEl = this.initFilters[key];
#                                 const currentEl = window.sideFilters[key];
#                                 if (key == 'filters_excluded'){
#                                     const sub = initEl.filter(x => !currentEl.includes(x)).length;
#                                     const add = currentEl.filter(x => !initEl.includes(x)).length;
#                                     this.applying = sub > 0 || add > 0;
#                                 } else if (Array.isArray(currentEl)){
#                                     diffMinus += initEl.filter(x => !currentEl.includes(x)).length;
#                                     diffPlus += currentEl.filter(x => !initEl.includes(x)).length;
#                                 }else if ((currentEl && initEl[0] !== currentEl) || currentEl == null){
#                                     if (!initEl) diffPlus++;
#                                     if (!currentEl) diffMinus++;
#                                     this.applying = true;
#                                 }
#
#                                 // Logic for platform (reverse filter)
#                                 if (key === 'platform') {
#                                     if (ignorePlatformApply) {
#                                         this.applying = false;
#                                         diffMinus = diffPlus = 0;
#                                     } else {
#                                         if (diffMinus || diffPlus) this.applying = true;
#                                         if (!urlParams.searchParams.get('platform')) {
#                                             diffPlus = countAvailablePlatforms - diffMinus;
#                                             diffMinus = 0;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#
#                         const initFiltersKeys = Object.keys(this.initFilters);
#                         const currentFiltersKeys = Object.keys(window.sideFilters);
#
#                         const initFiltersDiff = initFiltersKeys.filter(x => !currentFiltersKeys.includes(x));
#                         const currentFiltersDiff = currentFiltersKeys.filter(x => !initFiltersKeys.includes(x));
#
#                         initFiltersDiff.forEach(key => {
#                             diffMinus += Array.isArray(window.sideFilters[key]) ? this.initFilters[key].length : (window.sideFilters[key] ? 1 : 0);
#                         });
#                         currentFiltersDiff.forEach(key => {
#                             diffPlus += Array.isArray(window.sideFilters[key]) ? window.sideFilters[key].length : (window.sideFilters[key] ? 1 : 0);
#                         });
#
#                         if (diffMinus || diffPlus) this.applying = true;
#
#                         this.diffMinus = diffMinus;
#                         this.diffPlus = diffPlus;
#                     }
#                 }
#             }
#   </script>
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'829520b86d6c32be',t:'MTcwMDUyOTgxMS42MDUwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#   <iframe height="1" style="position: absolute; top: 0px; left: 0px; border: none; visibility: hidden;" width="1">
#   </iframe>
#   <script id="" type="text/javascript">
#    (function(){for(var b=document.querySelectorAll(".side-banner_sc"),c='\x3cdiv class\x3d"mt-6"\x3e\x3cins data-revive-zoneid\x3d"13429" data-revive-id\x3d"727bec5e09208690b050ccfc6a45d384"\x3e\x3c/ins\x3e\x3c/div\x3e',a=0;a<b.length;a++)console.log("side-banner #"+a),b[a].insertAdjacentHTML("beforeend",c)})();
# (function(){for(var b=document.querySelectorAll(".horizontal-banner_sc"),c='\x3cdiv class\x3d"mt-6"\x3e\x3cins data-revive-zoneid\x3d"13478" data-revive-id\x3d"727bec5e09208690b050ccfc6a45d384"\x3e\x3c/ins\x3e\x3c/div\x3e',a=0;a<b.length;a++)console.log("horizontal-banner #"+a),b[a].insertAdjacentHTML("beforeend",c)})();
#   </script>
#   <script id="" src="//servedby.revive-adserver.net/asyncjs.php" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
table = webpage.find("table", {"x-ref":"table"})
print(table.prettify())
# Out:
# <table class="md-max:min-w-max w-full bg-card text-secondary screen-content" wire:key="1700529649" x-ref="table">
#  <thead class="relative text-xs font-bold leading-4 text-left capitalize -z-1">
#   <tr class="">
#    <th class="border-b border-gray-dark th-cell pl-6 pr-0 w-12 cell_export h-14" data-filterid="sorting-table-th" data-value='&lt;svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16"&gt;&lt;path d="M5.333 2.667H14V4H5.333V2.667zM2 2.333h2v2H2v-2zM2 7h2v2H2V7zm0 4.667h2v2H2v-2zm3.333-4.334H14v1.334H5.333V7.333zm0 4.667H14v1.333H5.333V12z"/&gt;&lt;/svg&gt;'>
#     <div class="opacity-75 justify-start flex flex-1 items-center">
#      <svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#       <path d="M5.333 2.667H14V4H5.333V2.667zM2 2.333h2v2H2v-2zM2 7h2v2H2V7zm0 4.667h2v2H2v-2zm3.333-4.334H14v1.334H5.333V7.333zm0 4.667H14v1.333H5.333V12z">
#       </path>
#      </svg>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell sticky px-3 py-5 left-0 z-10 bg-card cell_export h-14" data-filterid="sorting-table-th" data-value='&lt;svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" width="16" height="16" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 16 16"&gt;&lt;path d="M10.263 13.82l-3.08-5.645L9.618 4.12l5.173 9.7h-4.527zM5.09 6.707l3.88 7.113H1.21l3.88-7.113zM3.473 5.413a1.617 1.617 0 1 1 0-3.233 1.617 1.617 0 0 1 0 3.233z"/&gt;&lt;/svg&gt;'>
#     <div class="opacity-75 justify-center flex flex-1 items-center">
#      <svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#       <path d="M10.263 13.82l-3.08-5.645L9.618 4.12l5.173 9.7h-4.527zM5.09 6.707l3.88 7.113H1.21l3.88-7.113zM3.473 5.413a1.617 1.617 0 1 1 0-3.233 1.617 1.617 0 0 1 0 3.233z">
#       </path>
#      </svg>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell px-2 py-1 cell_export h-14" data-filterid="sorting-table-th" data-value="Channel name">
#     <div class="opacity-75 justify-start flex flex-1 items-center">
#      Channel name
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell whitespace-nowrap max-w-5 pl-2 cell_export_hidden h-14" data-filterid="sorting-table-th" data-value="Add. Info">
#     <div class="opacity-75 justify-start flex flex-1 items-center">
#      Add. Info
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell px-2 py-1 cell_export_hidden h-14" data-filterid="sorting-table-th" data-value="">
#     <div class="opacity-75 justify-start flex flex-1 items-center">
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell pr-2 cell_export_hidden h-14" data-filterid="sorting-table-th" data-value="">
#     <div class="opacity-75 justify-start flex flex-1 items-center">
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell px-2 py-1 cell_export_hidden h-14" data-filterid="sorting-table-th" data-value='&lt;svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 16 16"&gt;&lt;path fill-rule="evenodd" d="M8.58 10.046L6.886 8.373l.02-.02A11.68 11.68 0 0 0 9.38 4h1.953V2.666H6.666V1.333H5.333v1.333H.667v1.327h7.446A10.475 10.475 0 0 1 6 7.566a10.43 10.43 0 0 1-1.54-2.233H3.127a11.708 11.708 0 0 0 1.986 3.04L1.72 11.72l.947.946L6 9.333l2.073 2.073.507-1.36zm3.753-3.38H11l-3 8h1.333l.747-2h3.166l.754 2h1.333l-3-8zm-1.747 4.667l1.08-2.887 1.08 2.887h-2.16z" clip-rule="evenodd"/&gt;&lt;/svg&gt;'>
#     <div class="opacity-75 justify-start flex flex-1 items-center">
#      <svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#       <path clip-rule="evenodd" d="M8.58 10.046L6.886 8.373l.02-.02A11.68 11.68 0 0 0 9.38 4h1.953V2.666H6.666V1.333H5.333v1.333H.667v1.327h7.446A10.475 10.475 0 0 1 6 7.566a10.43 10.43 0 0 1-1.54-2.233H3.127a11.708 11.708 0 0 0 1.986 3.04L1.72 11.72l.947.946L6 9.333l2.073 2.073.507-1.36zm3.753-3.38H11l-3 8h1.333l.747-2h3.166l.754 2h1.333l-3-8zm-1.747 4.667l1.08-2.887 1.08 2.887h-2.16z" fill-rule="evenodd">
#       </path>
#      </svg>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell px-2 t-cell--sm cell_export_hidden h-14" data-filterid="sorting-table-th" data-value='&lt;svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" width="16" height="16" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 16 16"&gt;
#     &lt;path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z" /&gt;
# &lt;/svg&gt;'>
#     <div class="opacity-75 justify-center flex flex-1 items-center">
#      <svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#       <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#       </path>
#      </svg>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell px-2 py-1 cell_export_hidden h-14" data-filterid="sorting-table-th" data-value='&lt;svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 16 16"&gt;&lt;path d="M1.335 12H8v1.332H1.335V12zm0-4.666h13.33v1.333H1.335V7.334zm0-4.666h13.33v1.333H1.335V2.668z"/&gt;&lt;/svg&gt;'>
#     <div class="opacity-75 justify-center flex flex-1 items-center">
#      <svg class="fill-current w-4 h-4 flex-shrink-0 w-4 h-4" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#       <path d="M1.335 12H8v1.332H1.335V12zm0-4.666h13.33v1.333H1.335V7.334zm0-4.666h13.33v1.333H1.335V2.668z">
#       </path>
#      </svg>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell whitespace-nowrap px-2 cell_export_hidden h-14" data-filterid="sorting-table-th" data-value="Followers">
#     <div class="flex flex-1 items-center justify-end">
#      <button aria-label="Sort" class="font-bold focus:outline-none flex mr-2 hidden" data-filterid="sorting-table-th-hidden" x-on:click="
#                                                 if (sortRedirects('followers', 'asc')) {
#                                                     $wire.call('sort', 'followers');
#                                                 }
#                                             ">
#       <span class="hidden h-4 w-4 fill-current transform rotate-180">
#        <svg class="w-4 h-4 fill-current text-secondary" name="sort-up" title="sort-up">
#         <use class="fill-current" href="/sprite.svg?v=1.11#icon-sort-up">
#         </use>
#        </svg>
#       </span>
#       <span class="hidden h-4 w-4 fill-current">
#        <svg class="w-4 h-4 fill-current text-secondary" name="sort-up" title="sort-up">
#         <use class="fill-current" href="/sprite.svg?v=1.11#icon-sort-up">
#         </use>
#        </svg>
#       </span>
#      </button>
#      <button class="inline-flex font-bold text-right focus:outline-none" x-on:click="
#                                                 if (sortRedirects('followers', 'asc')) {
#                                                     $wire.call('sort', 'followers');
#                                                 }
#                                             ">
#       <div class="opacity-75 font-bold">
#        Followers
#       </div>
#      </button>
#      <div class="flex ml-2 top-hide">
#       <svg class="w-4 h-4 fill-current opacity-75 w-4 h-4" data-tippy-content="The number of users following the channel." name="information" title="information">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#        </use>
#       </svg>
#      </div>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell whitespace-nowrap px-2 cell_export h-14" data-filterid="sorting-table-th" data-value="Peak Viewers">
#     <div class="flex flex-1 items-center justify-end">
#      <button aria-label="Sort" class="font-bold focus:outline-none flex mr-2 text-secondary" data-filterid="sorting-table-th-hidden" x-on:click="
#                                                 if (sortRedirects('peak_viewers', 'asc')) {
#                                                     $wire.call('sort', 'peak_viewers');
#                                                 }
#                                             ">
#       <span class="hidden h-4 w-4 fill-current transform rotate-180">
#        <svg class="w-4 h-4 fill-current text-secondary" name="sort-up" title="sort-up">
#         <use class="fill-current" href="/sprite.svg?v=1.11#icon-sort-up">
#         </use>
#        </svg>
#       </span>
#       <span class="text-secondary h-4 w-4 fill-current">
#        <svg class="w-4 h-4 fill-current text-secondary" name="sort-up" title="sort-up">
#         <use class="fill-current" href="/sprite.svg?v=1.11#icon-sort-up">
#         </use>
#        </svg>
#       </span>
#      </button>
#      <button class="inline-flex font-bold text-right focus:outline-none" x-on:click="
#                                                 if (sortRedirects('peak_viewers', 'asc')) {
#                                                     $wire.call('sort', 'peak_viewers');
#                                                 }
#                                             ">
#       <div class="font-bold">
#        Peak Viewers
#       </div>
#      </button>
#      <div class="flex ml-2 top-hide">
#       <svg class="w-4 h-4 fill-current w-4 h-4" data-tippy-content="The highest number of viewers watching a content unit, game, channel, etc. simultaneously." name="information" title="information">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#        </use>
#       </svg>
#      </div>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell whitespace-nowrap px-2 cell_export h-14" data-filterid="sorting-table-th" data-value="Average Viewers">
#     <div class="opacity-75 justify-end flex flex-1 items-center">
#      Average Viewers
#      <div class="flex ml-2 top-hide">
#       <svg class="w-4 h-4 fill-current opacity-75 w-4 h-4" data-tippy-content="The average number of viewers watching a content unit, game, channel, etc. simultaneously." name="information" title="information">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-information">
#        </use>
#       </svg>
#      </div>
#     </div>
#    </th>
#    <th class="border-b border-gray-dark th-cell whitespace-nowrap pr-6 cell_export_hidden h-14" data-filterid="sorting-table-th" data-value="Popular Games">
#     <div class="opacity-75 justify-end flex flex-1 items-center">
#      Popular Games
#     </div>
#    </th>
#   </tr>
#  </thead>
#  <tbody class="max-w-min" wire:loading.class="opacity-50">
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-card pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     1
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_avatar sticky text-secondary cell_export">
#     <img alt="ibai" class="t_i t_i_avatar t_i_c ld" decoding="async" height="28" loading="lazy" onload="this.classList.add('ld')" src="https://static-cdn.jtvnw.net/jtv_user_pictures/574228be-01ef-4eab-bc0e-a4f6b68bedba-profile_image-28x28.png" width="28"/>
#     <svg class="fill-current t_p_i_s flex-shrink-0 w-4 h-4" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#      <path d="M7.95243 3.33337L4.3999 6.8859V18.2858H7.25705L7.25705 23.4951L12.4664 18.2858H14.3712L19.8285 12.8285L19.8285 3.33337H7.95243Z">
#      </path>
#      <path d="M8.78086 5.33337L6.3999 7.71433L6.3999 16.2858L9.25704 16.2858L9.25704 18.6667L11.638 16.2858L13.5428 16.2858L17.8285 12L17.8285 5.33337L8.78086 5.33337Z" fill="#9147FF">
#      </path>
#      <path d="M14.9711 13.4286L16.8759 11.5238L16.8759 6.28574L9.25684 6.28574L9.25684 13.4286L11.1616 13.4286L11.1616 15.3334L13.0664 13.4286L14.9711 13.4286Z" fill="white">
#      </path>
#      <path d="M12.1143 8.19037L13.0666 8.19037L13.0666 11.0475L12.1143 11.0475L12.1143 8.19037ZM15.4476 8.19037L15.4476 11.0475L14.4952 11.0475L14.4952 8.19037L15.4476 8.19037Z" fill="#9147FF">
#      </path>
#     </svg>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-2 flex items-center text-secondary cell_export">
#     <div class="t_c_d_c t_c_d_c--md">
#      <a class="channel_name_c t_c_t t_c_t--channel-name" href="https://streamscharts.com/channels/ibai" title="ibai">
#       <span class="t_c_t_c t_c_t_c--channel-name" title="ibai">
#        ibai
#       </span>
#      </a>
#      <span class="t_c_s_l">
#       ES
#      </span>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-2 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Partner" class="t_c_t_iс mr-2 !ml-0" data-tippy-content="Partner" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/verification-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-0 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Male" class="t_c_t_iс mr-2 !ml-0 top-hide" data-tippy-content="Male" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/male.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-0 pr-2 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Spain" class="t_c_t_iс mr-2 !ml-0 f top-hide" data-tippy-content="Spain" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/flags/es.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="tag xs rounded bg-secondary text-secondary uppercase" data-tippy-content="Spanish" style="background-color: rgba(secondary, 0.1); color: rgb(secondary)">
#      es
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_game-avatar text-secondary cell_export_hidden">
#     <img alt="Sports" class="t_i rounded-sm t_i_game-avatar t_i_g ld" data-tippy-content="Sports" decoding="async" height="36" loading="lazy" onload="this.classList.add('ld')" src="https://static-cdn.jtvnw.net/ttv-boxart/518203-40x56.jpg" width="26"/>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pr-2 pl-2 text-secondary cell_export_hidden">
#     <div class="fv_c">
#      <button aria-label="Edit list" class="fv_b" data-channed_lists="[]" id="fv_b-83232866" x-data="" x-on:mouseover="$dispatch('show-list-popup', {
#             x: $refs.button.getBoundingClientRect().left + document.body.scrollLeft,
#             y: $refs.button.getBoundingClientRect().top + window.pageYOffset || document.documentElement.scrollTop,
#             channel_lists: JSON.parse($el.dataset.channed_lists),
#             channel_id: '83232866',
#             platform_id: 1,
#         }); $el.classList.add('fv_b-active'); document.querySelector('.fv_p input').focus()" x-ref="button">
#       <svg class="w-4 h-4 fill-current text-secondary" name="list-add" title="list-add">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-list-add">
#        </use>
#       </svg>
#      </button>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card px-1.5 text-secondary cell_export_hidden">
#     <div class="t_v text-xs">
#      15 308 628
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-violet-default));
#             --p_w: 81.345873587917%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card px-1.5 text-default cell_export">
#     <div class="t_v text-sm font-bold">
#      <span class="text-xxs opacity-50 font-normal pr-2">
#       Jul 01, 2023
#      </span>
#      3 442 745
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-rose-default));
#             --p_w: 100%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card px-1.5 text-secondary cell_export">
#     <div class="t_v text-xs">
#      55 651
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-yellow-default));
#             --p_w: 25.111553570314%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pr-6 cell_export_hidden">
#     <div class="flex flex-col min-w-0 text-default">
#      <div class="relative flex items-center text-xs">
#       <div class="w-full min-h-5 relative flex-shrink-0 text-right whitespace-nowrap">
#        <div class="flex items-center flex-shrink-0 space-x-1 w-max ml-auto">
#         <div class="x-img t_i_game-avatar" data-tippy-content="Just Chatting" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="Just Chatting" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/1/slug/just-chatting" width="26"/>
#         </div>
#         <div class="x-img t_i_game-avatar" data-tippy-content="League of Legends" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="League of Legends" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/1/slug/league-of-legends" width="26"/>
#         </div>
#         <div class="t_i_game-avatar bg-gray-dark rounded flex items-center justify-center text-xs text-secondary" data-tippy-content="Sports, Minecraft, Among Us">
#          +3
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-row pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     2
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row t_c_avatar sticky text-secondary cell_export">
#     <img alt="NIMO GALA 2023" class="t_i t_i_avatar t_i_c ld" decoding="async" height="28" loading="lazy" onload="this.classList.add('ld')" src="https://server-avatar.nimostatic.tv/1839511689862/202303061678091302152_1839511689862_avatar.png" width="28"/>
#     <svg class="fill-current t_p_i_s flex-shrink-0 w-4 h-4" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#      <path clip-rule="evenodd" d="M13.0676 3.56135C14.5663 2.86334 16.2324 3.84028 16.4803 5.35346C19.1226 5.50319 21.2068 7.69269 21.2068 10.3585V15.6525C21.2068 18.4198 18.9636 20.665 16.1943 20.665H7.80595C5.03864 20.665 2.79346 18.4218 2.79346 15.6525V10.3617C2.79346 7.63737 4.96745 5.414 7.68845 5.34995L9.21742 5.30246L13.0676 3.56135Z" fill-rule="evenodd">
#      </path>
#      <path d="M14.6013 7.31308C14.4353 7.30988 14.3087 7.16091 14.3332 6.99597L14.5066 5.81481C14.5524 5.48174 14.2087 5.23168 13.9054 5.37746L9.99695 7.14495C9.78413 7.24178 9.55322 7.29499 9.31805 7.30031L7.7421 7.34926C6.10338 7.38437 4.79346 8.72196 4.79346 10.3617V15.6525C4.79346 17.3168 6.14275 18.665 7.80595 18.665H16.1943C17.8586 18.665 19.2068 17.3157 19.2068 15.6525V10.3586C19.2068 8.72089 17.898 7.38224 16.2603 7.34606L14.6013 7.31308Z" fill="#622DF7">
#      </path>
#      <path d="M9.80093 12.1347C9.38486 12.1347 9.04541 11.7963 9.04541 11.3792C9.04541 10.9631 9.3838 10.6237 9.80093 10.6237C10.217 10.6237 10.5564 10.962 10.5564 11.3792C10.5564 11.7963 10.2181 12.1347 9.80093 12.1347Z" fill="white">
#      </path>
#      <path d="M14.5607 12.2975C14.4926 12.2975 14.4277 12.2762 14.3713 12.2369L13.5722 11.6782C13.4839 11.6165 13.4307 11.5143 13.4307 11.4058C13.4307 11.2972 13.4839 11.1962 13.5722 11.1334L14.3713 10.5737C14.4277 10.5343 14.4937 10.513 14.5607 10.513C14.7448 10.513 14.8938 10.662 14.8938 10.8461C14.8938 10.9546 14.8406 11.0568 14.7523 11.1185L14.3373 11.4047L14.7523 11.691C14.8417 11.7538 14.8938 11.8548 14.8938 11.9634C14.8938 12.056 14.8576 12.1411 14.7917 12.2039C14.7299 12.2635 14.6459 12.2975 14.5607 12.2975Z" fill="white">
#      </path>
#      <path d="M13.9425 13.3712L12.0814 12.2964C11.6259 12.0336 11.0566 12.3624 11.0566 12.8881V15.0365C11.0566 15.5622 11.6259 15.891 12.0814 15.6281L13.9414 14.5545C14.3979 14.2916 14.3979 13.634 13.9425 13.3712Z" fill="#FFD700">
#      </path>
#     </svg>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-2 flex items-center text-secondary cell_export">
#     <div class="t_c_d_c t_c_d_c--md">
#      <a class="channel_name_c t_c_t t_c_t--channel-name" href="https://streamscharts.com/channels/nimoglobalgala2023?platform=nimo" title="NIMO GALA 2023">
#       <span class="t_c_t_c t_c_t_c--channel-name" title="NIMO GALA 2023">
#        NIMO GALA 2023
#       </span>
#      </a>
#      <span class="t_c_s_l">
#       VI
#      </span>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-2 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-0 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Organization" class="t_c_t_iс mr-2 !ml-0 top-hide" data-tippy-content="Organization" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/company-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-0 pr-2 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Vietnam" class="t_c_t_iс mr-2 !ml-0 f top-hide" data-tippy-content="Vietnam" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/flags/vn.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="tag xs rounded bg-secondary text-secondary uppercase" data-tippy-content="Vietnamese" style="background-color: rgba(secondary, 0.1); color: rgb(secondary)">
#      vi
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row t_c_game-avatar text-secondary cell_export_hidden">
#     <img alt="GTA5" class="t_i rounded-sm t_i_game-avatar t_i_g ld" data-tippy-content="GTA5" decoding="async" height="36" loading="lazy" onload="this.classList.add('ld')" src="https://web-ops.nimostatic.tv/banner/4F5001B3D1DDBABB8F2C9E0567B4F6BF_GTA5.jpg" width="26"/>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pr-2 pl-2 text-secondary cell_export_hidden">
#     <div class="fv_c">
#      <button aria-label="Edit list" class="fv_b" data-channed_lists="[]" id="fv_b-2830004384" x-data="" x-on:mouseover="$dispatch('show-list-popup', {
#             x: $refs.button.getBoundingClientRect().left + document.body.scrollLeft,
#             y: $refs.button.getBoundingClientRect().top + window.pageYOffset || document.documentElement.scrollTop,
#             channel_lists: JSON.parse($el.dataset.channed_lists),
#             channel_id: '2830004384',
#             platform_id: 29,
#         }); $el.classList.add('fv_b-active'); document.querySelector('.fv_p input').focus()" x-ref="button">
#       <svg class="w-4 h-4 fill-current text-secondary" name="list-add" title="list-add">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-list-add">
#        </use>
#       </svg>
#      </button>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-secondary cell_export_hidden">
#     <div class="t_v text-xs">
#      0
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-violet-default));
#             --p_w: 0%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-default cell_export">
#     <div class="t_v text-xs">
#      <span class="text-xxs opacity-50 font-normal pr-2">
#       Apr 08, 2023
#      </span>
#      3 043 120
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-rose-default));
#             --p_w: 88.392256760231%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-secondary cell_export">
#     <div class="t_v text-xs">
#      37 218
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-yellow-default));
#             --p_w: 16.794058066975%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pr-6 cell_export_hidden">
#     <div class="flex flex-col min-w-0 text-default">
#      <div class="relative flex items-center text-xs">
#       <div class="w-full min-h-5 relative flex-shrink-0 text-right whitespace-nowrap">
#        <div class="flex items-center flex-shrink-0 space-x-1 w-max ml-auto">
#         <div class="x-img t_i_game-avatar" data-tippy-content="GTA5" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="GTA5" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/29/slug/gta5" width="26"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-card pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     3
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_avatar sticky text-secondary cell_export">
#     <img alt="TheGrefg" class="t_i t_i_avatar t_i_c ld" decoding="async" height="28" loading="lazy" onload="this.classList.add('ld')" src="https://static-cdn.jtvnw.net/jtv_user_pictures/edc0529a-0250-4ad4-a77f-e3072ff29c81-profile_image-28x28.png" width="28"/>
#     <svg class="fill-current t_p_i_s flex-shrink-0 w-4 h-4" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#      <path d="M7.95243 3.33337L4.3999 6.8859V18.2858H7.25705L7.25705 23.4951L12.4664 18.2858H14.3712L19.8285 12.8285L19.8285 3.33337H7.95243Z">
#      </path>
#      <path d="M8.78086 5.33337L6.3999 7.71433L6.3999 16.2858L9.25704 16.2858L9.25704 18.6667L11.638 16.2858L13.5428 16.2858L17.8285 12L17.8285 5.33337L8.78086 5.33337Z" fill="#9147FF">
#      </path>
#      <path d="M14.9711 13.4286L16.8759 11.5238L16.8759 6.28574L9.25684 6.28574L9.25684 13.4286L11.1616 13.4286L11.1616 15.3334L13.0664 13.4286L14.9711 13.4286Z" fill="white">
#      </path>
#      <path d="M12.1143 8.19037L13.0666 8.19037L13.0666 11.0475L12.1143 11.0475L12.1143 8.19037ZM15.4476 8.19037L15.4476 11.0475L14.4952 11.0475L14.4952 8.19037L15.4476 8.19037Z" fill="#9147FF">
#      </path>
#     </svg>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-2 flex items-center text-secondary cell_export">
#     <div class="t_c_d_c t_c_d_c--md">
#      <a class="channel_name_c t_c_t t_c_t--channel-name" href="https://streamscharts.com/channels/thegrefg" title="TheGrefg">
#       <span class="t_c_t_c t_c_t_c--channel-name" title="TheGrefg">
#        TheGrefg
#       </span>
#      </a>
#      <span class="t_c_s_l">
#       ES
#      </span>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-2 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Partner" class="t_c_t_iс mr-2 !ml-0" data-tippy-content="Partner" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/verification-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-0 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Male" class="t_c_t_iс mr-2 !ml-0 top-hide" data-tippy-content="Male" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/male.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-0 pr-2 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Spain" class="t_c_t_iс mr-2 !ml-0 f top-hide" data-tippy-content="Spain" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/flags/es.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="tag xs rounded bg-secondary text-secondary uppercase" data-tippy-content="Spanish" style="background-color: rgba(secondary, 0.1); color: rgb(secondary)">
#      es
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_game-avatar text-secondary cell_export_hidden">
#     <img alt="Just Chatting" class="t_i rounded-sm t_i_game-avatar t_i_g ld" data-tippy-content="Just Chatting" decoding="async" height="36" loading="lazy" onload="this.classList.add('ld')" src="https://static-cdn.jtvnw.net/ttv-boxart/509658-40x56.jpg" width="26"/>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pr-2 pl-2 text-secondary cell_export_hidden">
#     <div class="fv_c">
#      <button aria-label="Edit list" class="fv_b" data-channed_lists="[]" id="fv_b-48878319" x-data="" x-on:mouseover="$dispatch('show-list-popup', {
#             x: $refs.button.getBoundingClientRect().left + document.body.scrollLeft,
#             y: $refs.button.getBoundingClientRect().top + window.pageYOffset || document.documentElement.scrollTop,
#             channel_lists: JSON.parse($el.dataset.channed_lists),
#             channel_id: '48878319',
#             platform_id: 1,
#         }); $el.classList.add('fv_b-active'); document.querySelector('.fv_p input').focus()" x-ref="button">
#       <svg class="w-4 h-4 fill-current text-secondary" name="list-add" title="list-add">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-list-add">
#        </use>
#       </svg>
#      </button>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card px-1.5 text-secondary cell_export_hidden">
#     <div class="t_v text-xs">
#      11 688 018
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-violet-default));
#             --p_w: 62.106939610872%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card px-1.5 text-default cell_export">
#     <div class="t_v text-xs">
#      <span class="text-xxs opacity-50 font-normal pr-2">
#       Jan 11, 2021
#      </span>
#      2 470 347
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-rose-default));
#             --p_w: 71.75515468035%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card px-1.5 text-secondary cell_export">
#     <div class="t_v text-xs">
#      24 613
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-yellow-default));
#             --p_w: 11.105872143457%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pr-6 cell_export_hidden">
#     <div class="flex flex-col min-w-0 text-default">
#      <div class="relative flex items-center text-xs">
#       <div class="w-full min-h-5 relative flex-shrink-0 text-right whitespace-nowrap">
#        <div class="flex items-center flex-shrink-0 space-x-1 w-max ml-auto">
#         <div class="x-img t_i_game-avatar" data-tippy-content="Just Chatting" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="Just Chatting" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/1/slug/just-chatting" width="26"/>
#         </div>
#         <div class="x-img t_i_game-avatar" data-tippy-content="Fortnite" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="Fortnite" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/1/slug/fortnite" width="26"/>
#         </div>
#         <div class="t_i_game-avatar bg-gray-dark rounded flex items-center justify-center text-xs text-secondary" data-tippy-content="Minecraft, Clash Royale, Valorant">
#          +3
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-row pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     4
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row t_c_avatar sticky text-secondary cell_export">
#     <img alt="MPL ID" class="t_i t_i_avatar t_i_c ld" decoding="async" height="28" loading="lazy" onload="this.classList.add('ld')" src="https://server-avatar.nimostatic.tv/1599514834517/202108131628834377915_1599514834517_avatar.png" width="28"/>
#     <svg class="fill-current t_p_i_s flex-shrink-0 w-4 h-4" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#      <path clip-rule="evenodd" d="M13.0676 3.56135C14.5663 2.86334 16.2324 3.84028 16.4803 5.35346C19.1226 5.50319 21.2068 7.69269 21.2068 10.3585V15.6525C21.2068 18.4198 18.9636 20.665 16.1943 20.665H7.80595C5.03864 20.665 2.79346 18.4218 2.79346 15.6525V10.3617C2.79346 7.63737 4.96745 5.414 7.68845 5.34995L9.21742 5.30246L13.0676 3.56135Z" fill-rule="evenodd">
#      </path>
#      <path d="M14.6013 7.31308C14.4353 7.30988 14.3087 7.16091 14.3332 6.99597L14.5066 5.81481C14.5524 5.48174 14.2087 5.23168 13.9054 5.37746L9.99695 7.14495C9.78413 7.24178 9.55322 7.29499 9.31805 7.30031L7.7421 7.34926C6.10338 7.38437 4.79346 8.72196 4.79346 10.3617V15.6525C4.79346 17.3168 6.14275 18.665 7.80595 18.665H16.1943C17.8586 18.665 19.2068 17.3157 19.2068 15.6525V10.3586C19.2068 8.72089 17.898 7.38224 16.2603 7.34606L14.6013 7.31308Z" fill="#622DF7">
#      </path>
#      <path d="M9.80093 12.1347C9.38486 12.1347 9.04541 11.7963 9.04541 11.3792C9.04541 10.9631 9.3838 10.6237 9.80093 10.6237C10.217 10.6237 10.5564 10.962 10.5564 11.3792C10.5564 11.7963 10.2181 12.1347 9.80093 12.1347Z" fill="white">
#      </path>
#      <path d="M14.5607 12.2975C14.4926 12.2975 14.4277 12.2762 14.3713 12.2369L13.5722 11.6782C13.4839 11.6165 13.4307 11.5143 13.4307 11.4058C13.4307 11.2972 13.4839 11.1962 13.5722 11.1334L14.3713 10.5737C14.4277 10.5343 14.4937 10.513 14.5607 10.513C14.7448 10.513 14.8938 10.662 14.8938 10.8461C14.8938 10.9546 14.8406 11.0568 14.7523 11.1185L14.3373 11.4047L14.7523 11.691C14.8417 11.7538 14.8938 11.8548 14.8938 11.9634C14.8938 12.056 14.8576 12.1411 14.7917 12.2039C14.7299 12.2635 14.6459 12.2975 14.5607 12.2975Z" fill="white">
#      </path>
#      <path d="M13.9425 13.3712L12.0814 12.2964C11.6259 12.0336 11.0566 12.3624 11.0566 12.8881V15.0365C11.0566 15.5622 11.6259 15.891 12.0814 15.6281L13.9414 14.5545C14.3979 14.2916 14.3979 13.634 13.9425 13.3712Z" fill="#FFD700">
#      </path>
#     </svg>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-2 flex items-center text-secondary cell_export">
#     <div class="t_c_d_c t_c_d_c--md">
#      <a class="channel_name_c t_c_t t_c_t--channel-name" href="https://streamscharts.com/channels/mpl-id?platform=nimo" title="MPL ID">
#       <span class="t_c_t_c t_c_t_c--channel-name" title="MPL ID">
#        MPL ID
#       </span>
#      </a>
#      <span class="t_c_s_l">
#       ID
#      </span>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-2 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-0 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt='Gender is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' class="t_c_t_iс mr-2 !ml-0 opacity-25 top-hide" data-tippy-content='Gender is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' decoding="async" delay-after="200" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/lock-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-0 pr-2 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt='Country is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' class="t_c_t_iс mr-2 !ml-0 opacity-25 top-hide" data-tippy-content='Country is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' decoding="async" delay-after="200" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/lock-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="tag xs rounded bg-secondary text-secondary uppercase" data-tippy-content="Indonesian" style="background-color: rgba(secondary, 0.1); color: rgb(secondary)">
#      id
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row t_c_game-avatar text-secondary cell_export_hidden">
#     <img alt="Mobile Legends" class="t_i rounded-sm t_i_game-avatar t_i_g ld" data-tippy-content="Mobile Legends" decoding="async" height="36" loading="lazy" onload="this.classList.add('ld')" src="https://web-ops.nimostatic.tv/banner/D126C9C813178A85B313B491F29E6632_7f2de02df66074f3dbe5978b66a82158.png" width="26"/>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pr-2 pl-2 text-secondary cell_export_hidden">
#     <div class="fv_c">
#      <button aria-label="Edit list" class="fv_b" data-channed_lists="[]" id="fv_b-5348200" x-data="" x-on:mouseover="$dispatch('show-list-popup', {
#             x: $refs.button.getBoundingClientRect().left + document.body.scrollLeft,
#             y: $refs.button.getBoundingClientRect().top + window.pageYOffset || document.documentElement.scrollTop,
#             channel_lists: JSON.parse($el.dataset.channed_lists),
#             channel_id: '5348200',
#             platform_id: 29,
#         }); $el.classList.add('fv_b-active'); document.querySelector('.fv_p input').focus()" x-ref="button">
#       <svg class="w-4 h-4 fill-current text-secondary" name="list-add" title="list-add">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-list-add">
#        </use>
#       </svg>
#      </button>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-secondary cell_export_hidden">
#     <div class="t_v text-xs">
#      0
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-violet-default));
#             --p_w: 0%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-default cell_export">
#     <div class="t_v text-xs">
#      <span class="text-xxs opacity-50 font-normal pr-2">
#       Apr 09, 2022
#      </span>
#      1 503 628
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-rose-default));
#             --p_w: 43.675264941202%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-secondary cell_export">
#     <div class="t_v text-xs">
#      42 080
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-yellow-default));
#             --p_w: 18.987713523832%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pr-6 cell_export_hidden">
#     <div class="flex flex-col min-w-0 text-default">
#      <div class="relative flex items-center text-xs">
#       <div class="w-full min-h-5 relative flex-shrink-0 text-right whitespace-nowrap">
#        <div class="flex items-center flex-shrink-0 space-x-1 w-max ml-auto">
#         <div class="x-img t_i_game-avatar" data-tippy-content="Mobile Legends" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="Mobile Legends" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/29/slug/mobile-legends" width="26"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-card pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     5
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_avatar sticky text-secondary cell_export">
#     <img alt="Squeezie" class="t_i t_i_avatar t_i_c ld" decoding="async" height="28" loading="lazy" onload="this.classList.add('ld')" src="https://static-cdn.jtvnw.net/jtv_user_pictures/df3e5800-b524-4c4e-87b0-8b3646d9185a-profile_image-28x28.png" width="28"/>
#     <svg class="fill-current t_p_i_s flex-shrink-0 w-4 h-4" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#      <path d="M7.95243 3.33337L4.3999 6.8859V18.2858H7.25705L7.25705 23.4951L12.4664 18.2858H14.3712L19.8285 12.8285L19.8285 3.33337H7.95243Z">
#      </path>
#      <path d="M8.78086 5.33337L6.3999 7.71433L6.3999 16.2858L9.25704 16.2858L9.25704 18.6667L11.638 16.2858L13.5428 16.2858L17.8285 12L17.8285 5.33337L8.78086 5.33337Z" fill="#9147FF">
#      </path>
#      <path d="M14.9711 13.4286L16.8759 11.5238L16.8759 6.28574L9.25684 6.28574L9.25684 13.4286L11.1616 13.4286L11.1616 15.3334L13.0664 13.4286L14.9711 13.4286Z" fill="white">
#      </path>
#      <path d="M12.1143 8.19037L13.0666 8.19037L13.0666 11.0475L12.1143 11.0475L12.1143 8.19037ZM15.4476 8.19037L15.4476 11.0475L14.4952 11.0475L14.4952 8.19037L15.4476 8.19037Z" fill="#9147FF">
#      </path>
#     </svg>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-2 flex items-center text-secondary cell_export">
#     <div class="t_c_d_c t_c_d_c--md">
#      <a class="channel_name_c t_c_t t_c_t--channel-name" href="https://streamscharts.com/channels/squeezie" title="Squeezie">
#       <span class="t_c_t_c t_c_t_c--channel-name" title="Squeezie">
#        Squeezie
#       </span>
#      </a>
#      <span class="t_c_s_l">
#       FR
#      </span>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-2 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt="Partner" class="t_c_t_iс mr-2 !ml-0" data-tippy-content="Partner" decoding="async" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/verification-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-0 pr-0 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt='Gender is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' class="t_c_t_iс mr-2 !ml-0 opacity-25 top-hide" data-tippy-content='Gender is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' decoding="async" delay-after="200" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/lock-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pl-0 pr-2 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt='Country is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' class="t_c_t_iс mr-2 !ml-0 opacity-25 top-hide" data-tippy-content='Country is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' decoding="async" delay-after="200" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/lock-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="tag xs rounded bg-secondary text-secondary uppercase" data-tippy-content="French" style="background-color: rgba(secondary, 0.1); color: rgb(secondary)">
#      fr
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_game-avatar text-secondary cell_export_hidden">
#     <img alt="Fortnite" class="t_i rounded-sm t_i_game-avatar t_i_g ld" data-tippy-content="Fortnite" decoding="async" height="36" loading="lazy" onload="this.classList.add('ld')" src="https://static-cdn.jtvnw.net/ttv-boxart/33214-40x56.jpg" width="26"/>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card pr-2 pl-2 text-secondary cell_export_hidden">
#     <div class="fv_c">
#      <button aria-label="Edit list" class="fv_b" data-channed_lists="[]" id="fv_b-52130765" x-data="" x-on:mouseover="$dispatch('show-list-popup', {
#             x: $refs.button.getBoundingClientRect().left + document.body.scrollLeft,
#             y: $refs.button.getBoundingClientRect().top + window.pageYOffset || document.documentElement.scrollTop,
#             channel_lists: JSON.parse($el.dataset.channed_lists),
#             channel_id: '52130765',
#             platform_id: 1,
#         }); $el.classList.add('fv_b-active'); document.querySelector('.fv_p input').focus()" x-ref="button">
# ...
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pl-0 pr-2 text-secondary cell_export_hidden">
#     <div class="t_c_d_c t_c_d_c--sm">
#      <div class="t_c_s">
#       <img alt='Country is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' class="t_c_t_iс mr-2 !ml-0 opacity-25 top-hide" data-tippy-content='Country is available for &lt;a href="/pricing" target="_blank" class="text-primary"&gt;PRO&lt;/a&gt; users only' decoding="async" delay-after="200" height="12" loading="lazy" onerror="this.classList.add('hidden')" src="https://static.streamscharts.com/img/icons/lock-fill.svg?ver=1" width="12"/>
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="tag xs rounded bg-secondary text-secondary uppercase" data-tippy-content="Korean" style="background-color: rgba(secondary, 0.1); color: rgb(secondary)">
#      ko
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row t_c_game-avatar text-secondary cell_export_hidden">
#     <img alt="Teamfight Tactics" class="t_i rounded-sm t_i_game-avatar t_i_g ld" data-tippy-content="Teamfight Tactics" decoding="async" height="36" loading="lazy" onload="this.classList.add('ld')" src="https://static-cdn.jtvnw.net/ttv-boxart/513143-40x56.jpg" width="26"/>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pr-2 pl-2 text-secondary cell_export_hidden">
#     <div class="fv_c">
#      <div class="fv_i bg-254,126,241" style="background-color: rgb(254,126,241)">
#      </div>
#      <div class="fv_i mt-0.5 bg-255,255,255" style="background-color: rgb(255,255,255)">
#      </div>
#      <button aria-label="Edit list" class="fv_b" data-channed_lists="[69,94]" id="fv_b-190835892" x-data="" x-on:mouseover="$dispatch('show-list-popup', {
#             x: $refs.button.getBoundingClientRect().left + document.body.scrollLeft,
#             y: $refs.button.getBoundingClientRect().top + window.pageYOffset || document.documentElement.scrollTop,
#             channel_lists: JSON.parse($el.dataset.channed_lists),
#             channel_id: '190835892',
#             platform_id: 1,
#         }); $el.classList.add('fv_b-active'); document.querySelector('.fv_p input').focus()" x-ref="button">
#       <svg class="w-4 h-4 fill-current text-secondary" name="list-add" title="list-add">
#        <use class="fill-current" href="/sprite.svg?v=1.11#icon-list-add">
#        </use>
#       </svg>
#      </button>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-secondary cell_export_hidden">
#     <div class="t_v text-xs">
#      1 331 677
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-violet-default));
#             --p_w: 7.076168347806%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-default cell_export">
#     <div class="t_v text-xs">
#      <span class="text-xxs opacity-50 font-normal pr-2">
#       Nov 06, 2022
#      </span>
#      692 626
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-rose-default));
#             --p_w: 20.118422944482%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row px-1.5 text-secondary cell_export">
#     <div class="t_v text-xs">
#      40 631
#     </div>
#     <div class="t_p">
#      <div class="t_p_a" style="
#             --p_c: rgb(var(--color-yellow-default));
#             --p_w: 18.333703462797%;
#         ">
#      </div>
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row pr-6 cell_export_hidden">
#     <div class="flex flex-col min-w-0 text-default">
#      <div class="relative flex items-center text-xs">
#       <div class="w-full min-h-5 relative flex-shrink-0 text-right whitespace-nowrap">
#        <div class="flex items-center flex-shrink-0 space-x-1 w-max ml-auto">
#         <div class="x-img t_i_game-avatar" data-tippy-content="Valorant" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="Valorant" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/1/slug/valorant" width="26"/>
#         </div>
#         <div class="x-img t_i_game-avatar" data-tippy-content="Teamfight Tactics" delay-after="100">
#          <div class="t_i_game-avatar x-img-ph">
#           <svg class="fill-current w-4 h-4 text-secondary text-opacity-30" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10 5V1.333H6V5l2 2 2-2zM5 6H1.333v4H5l2-2-2-2zm1 5v3.667h4V11L8 9l-2 2zm5-5L9 8l2 2h3.667V6H11z">
#            </path>
#           </svg>
#          </div>
#          <img alt="Teamfight Tactics" class="relative t_i_game-avatar" decoding="async" height="36" loading="lazy" onerror="this.classList.add('!hidden'); " onload="this.closest('.x-img').classList.add('ld');" src="https://cdnr.escharts.com/games/1/slug/teamfight-tactics" width="26"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group" x-ref="rowLockedFrom">
#    <td class="ticker-hover px-2 t-cell bg-card pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     21
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_avatar sticky text-secondary cell_export">
#     <div class="rounded-full w-7 h-7 !bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-2 pr-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-2 pl-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-1 text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export">
#     <div class="w-5 mx-auto rounded-sm h-7 bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card cell_export">
#     <div class="flex flex-col min-w-0 text-default">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-default cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-row pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     22
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row t_c_avatar sticky text-secondary cell_export">
#     <div class="rounded-full w-7 h-7 !bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row mr-2 pr-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row mr-2 pl-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row mr-1 text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export">
#     <div class="w-5 mx-auto rounded-sm h-7 bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export">
#     <div class="w-1.5 mx-auto rounded-sm h-1.5 bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-default cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-card pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     23
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_avatar sticky text-secondary cell_export">
#     <div class="rounded-full w-7 h-7 !bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-2 pr-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-2 pl-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-1 text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export">
#     <div class="w-5 mx-auto rounded-sm h-7 bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card cell_export">
#     <div class="flex flex-col min-w-0 text-default">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-default cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-row pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     24
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row t_c_avatar sticky text-secondary cell_export">
#     <div class="rounded-full w-7 h-7 !bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row mr-2 pr-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row mr-2 pl-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row mr-1 text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export">
#     <div class="w-5 mx-auto rounded-sm h-7 bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export">
#     <div class="w-1.5 mx-auto rounded-sm h-1.5 bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-default cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-row text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#   </tr>
#   <tr class="text-sm group">
#    <td class="ticker-hover px-2 t-cell bg-card pl-6 pr-1 w-12 !text-secondary text-xs !text-opacity-75 text-secondary cell_export">
#     25
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card t_c_avatar sticky text-secondary cell_export">
#     <div class="rounded-full w-7 h-7 !bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-2 pr-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-2 pl-0 text-secondary cell_export">
#     <div class="w-3 h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card mr-1 text-secondary cell_export">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export">
#     <div class="w-5 mx-auto rounded-sm h-7 bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card cell_export">
#     <div class="flex flex-col min-w-0 text-default">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-default cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#    <td class="ticker-hover px-2 t-cell bg-card text-secondary cell_export_hidden">
#     <div class="w-full h-3 rounded-sm bg-gray-dark">
#     </div>
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
column_names = ["Rank", "Platform", "Channel Name", "Partnered", "Gender", "Country", "Region", "My Lists", "Sort", "Followers", "Peak Viewers", "Average Viewers", "Popular Categories"]
table_rows = table.find("tbody").find_all("tr")

# %%
l = []
for tr in table_rows:
    td = tr.find_all("td")
    row = [str(tr.get_text()).strip() for tr in td]
    l.append(row)

df = pd.DataFrame(l, columns=column_names)
df.head()
# Out:
#   Rank Platform            Channel Name Partnered Gender Country Region  \
# 0    1                     ibai\n\n\nES                              es
# 1    2           NIMO GALA 2023\n\n\nVI                              vi
# 2    3                 TheGrefg\n\n\nES                              es
# 3    4                   MPL ID\n\n\nID                              id
# 4    5                 Squeezie\n\n\nFR                              fr
#
#   My Lists Sort   Followers               Peak Viewers Average Viewers  \
# 0                15 308 628  Jul 01, 2023\n\n3 442 745          55 651
# 1                         0  Apr 08, 2023\n\n3 043 120          37 218
# 2                11 688 018  Jan 11, 2021\n\n2 470 347          24 613
# 3                         0  Apr 09, 2022\n\n1 503 628          42 080
# 4                 4 832 764  Sep 09, 2023\n\n1 340 960          23 069
#
#   Popular Categories
# 0                 +3
# 1
# 2                 +3
# 3
# 4                 +3

# %%
df.drop(df.tail(5).index, inplace=True)

# %%
drop_col = ["Partnered", "Gender", "Country", "My Lists", "Sort"]
df = df.drop(columns=drop_col)

# %%
df.loc[1, "Followers"] = "52,009"
df.loc[3, "Followers"] = "1,421,167"
df.loc[11, "Followers"] = "2,331,509"

# %%
df["Channel Name"] = [name.replace("\n", "")[:-2] for name in df["Channel Name"]]
df["Region"] = [region.upper() for region in df["Region"]]
df["Peak Viewers"] = [viewers[14:].replace(" ", ",") for viewers in df["Peak Viewers"]]
df["Average Viewers"] = [average.replace(" ", ",") for average in df["Average Viewers"]]
df["Followers"] = [followers.replace(" ", ",") for followers in df["Followers"]]

# %%
first_fill_values = []
svg_elements = table.find_all("svg")

for svg in svg_elements:
    path_elements = svg.find_all("path")
    for path in path_elements:
        fill_value = path.get("fill")
        if fill_value is not None:
            first_fill_values.append(fill_value)
            break

# %%
first_fill_values
# Out:
# ['#9147FF',
#  '#622DF7',
#  '#9147FF',
#  '#622DF7',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#622DF7',
#  '#9147FF',
#  '#050509',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF',
#  '#9147FF']

# %%
platform_dict = {"#9147FF":"Twitch", "#622DF7":"Nimo TV", "#050509":"Kick"}

# %%
platform_list = [platform_dict[key] for key in first_fill_values]
platform_list
# Out:
# ['Twitch',
#  'Nimo TV',
#  'Twitch',
#  'Nimo TV',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Nimo TV',
#  'Twitch',
#  'Kick',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Twitch',
#  'Twitch']

# %%
df["Platform"] = platform_list

# %%
pattern = re.compile(r'ticker-hover px-2 t-cell bg-(card|row) pr-6 cell_export_hidden')
td_elements = table.find_all("td", {"class":pattern})

# %%
data_tippy_content = []

for td in td_elements:
    td_list = []
    div_elements = td.find_all("div", {"class":"x-img t_i_game-avatar"})
    plus3 = td.find_all("div", {"class":"t_i_game-avatar bg-gray-dark rounded flex items-center justify-center text-xs text-secondary"})
    for div in div_elements:
        tippy_value = div.get("data-tippy-content")
        if tippy_value is not None:
            td_list.append(tippy_value)
    for three in plus3:
        value3 = three.get("data-tippy-content")
        if value3 is not None:
            td_list.append(value3)
    data_tippy_content.append(td_list)

# %%
data_tippy_content
# Out:
# [['Just Chatting', 'League of Legends', 'Sports, Minecraft, Among Us'],
#  ['GTA5'],
#  ['Just Chatting', 'Fortnite', 'Minecraft, Clash Royale, Valorant'],
#  ['Mobile Legends'],
#  ['Just Chatting', 'League of Legends', 'Valorant, Among Us, Minecraft'],
#  ['Just Chatting', 'World of Warcraft', 'League of Legends, Rust, '],
#  ['Just Chatting',
#   'Grand Theft Auto V',
#   'League of Legends, Fall Guys: Ultimate Knockout, FIFA 21'],
#  ['Magic: The Gathering',
#   'Rocket League',
#   'Just Chatting, Mortal Kombat 11, FIFA 21'],
#  ['Sports', 'Special Events'],
#  ['Mortal Kombat 11',
#   'Tekken 7',
#   'Apex Legends, Soulcalibur VI, Guilty Gear -Strive-'],
#  ['League of Legends',
#   'Teamfight Tactics',
#   'League of Legends: Wild Rift, Valorant, Legends of Runeterra'],
#  ['GTA5', 'PUBG'],
#  ['Dota 2'],
#  ['Just Chatting',
#   'Call of Duty: Warzone 2.0, Special Events, Call of Duty: Warzone'],
#  ['Unknown'],
#  ['Valorant',
#   'Just Chatting',
#   'World of Warcraft, TrackMania, Special Events'],
#  ['Fortnite'],
#  ['Minecraft', 'Just Chatting', ', Fall Guys: Ultimate Knockout, Fortnite'],
#  ['Counter-Strike', 'Just Chatting', 'Among Us, Sports, Motorsport Manager'],
#  ['Valorant', 'Teamfight Tactics']]

# %%
df["Popular Categories"] = data_tippy_content

# %%
columns_to_int = ['Followers', 'Peak Viewers', 'Average Viewers']
df[columns_to_int] = df[columns_to_int].apply(lambda x: x.str.replace(',', '').astype(int))

# %%
def split_categories(list_input):
    return str(list_input).replace("'", "").strip("[]").split(", ")

df["Popular Categories"] = df["Popular Categories"].apply(lambda x: split_categories(x))

# %%
df["Popular Categories"] = [item for item in df["Popular Categories"] if item != '']
df["Popular Categories"]
# Out:
# 0     [Just Chatting, League of Legends, Sports, Min...
# 1                                                [GTA5]
# 2     [Just Chatting, Fortnite, Minecraft, Clash Roy...
# 3                                      [Mobile Legends]
# 4     [Just Chatting, League of Legends, Valorant, A...
# 5     [Just Chatting, World of Warcraft, League of L...
# 6     [Just Chatting, Grand Theft Auto V, League of ...
# 7     [Magic: The Gathering, Rocket League, Just Cha...
# 8                              [Sports, Special Events]
# 9     [Mortal Kombat 11, Tekken 7, Apex Legends, Sou...
# 10    [League of Legends, Teamfight Tactics, League ...
# 11                                         [GTA5, PUBG]
# 12                                             [Dota 2]
# 13    [Just Chatting, Call of Duty: Warzone 2.0, Spe...
# 14                                            [Unknown]
# 15    [Valorant, Just Chatting, World of Warcraft, T...
# 16                                           [Fortnite]
# 17    [Minecraft, Just Chatting, Fall Guys: Ultimate...
# 18    [Counter-Strike, Just Chatting, Among Us, Spor...
# 19                        [Valorant, Teamfight Tactics]
# Name: Popular Categories, dtype: object

# %%
df
# Out:
#    Rank Platform        Channel Name Region  Followers  Peak Viewers  \
# 0     1   Twitch                ibai     ES   15308628       3442745
# 1     2  Nimo TV      NIMO GALA 2023     VI      52009       3043120
# 2     3   Twitch            TheGrefg     ES   11688018       2470347
# 3     4  Nimo TV              MPL ID     ID    1421167       1503628
# 4     5   Twitch            Squeezie     FR    4832764       1340960
# 5     6   Twitch             elxokas     ES    3632399       1208144
# 6     7   Twitch          aminematue     FR    2369866       1155060
# 7     8   Twitch          ELEAGUE TV     EN    1602862       1130760
# 8     9   Twitch         kingsleague     ES    3001424       1108295
# 9    10   Twitch         PlayStation     EN     867020       1016962
# 10   11   Twitch          Riot Games     EN    6855513        990201
# 11   12  Nimo TV          MixiGaming     VI    2331509        984808
# 12   13   Twitch          dota2ti_ru     RU     955445        812818
# 13   14     Kick             westcol     ES     300721        806667
# 14   15   Twitch            onextwo_     EN      23785        767642
# 15   16   Twitch             ZeratoR     FR    1538665        720751
# 16   17   Twitch            Fortnite     EN    5640103        712682
# 17   18   Twitch         Shadoune666     ES    1823739        708568
# 18   19   Twitch              Gaules     PT    4022902        707648
# 19   20   Twitch  Riot_esports_Korea     KO    1331677        692626
#
#     Average Viewers                                 Popular Categories
# 0             55651  [Just Chatting, League of Legends, Sports, Min...
# 1             37218                                             [GTA5]
# 2             24613  [Just Chatting, Fortnite, Minecraft, Clash Roy...
# 3             42080                                   [Mobile Legends]
# 4             23069  [Just Chatting, League of Legends, Valorant, A...
# 5             11904  [Just Chatting, World of Warcraft, League of L...
# 6             16382  [Just Chatting, Grand Theft Auto V, League of ...
# 7              7069  [Magic: The Gathering, Rocket League, Just Cha...
# 8            122083                           [Sports, Special Events]
# 9              3986  [Mortal Kombat 11, Tekken 7, Apex Legends, Sou...
# 10            32216  [League of Legends, Teamfight Tactics, League ...
# 11           221617                                       [GTA5, PUBG]
# 12            67653                                           [Dota 2]
# 13            28919  [Just Chatting, Call of Duty: Warzone 2.0, Spe...
# 14            56475                                          [Unknown]
# 15            13951  [Valorant, Just Chatting, World of Warcraft, T...
# 16            21002                                         [Fortnite]
# 17             1222  [Minecraft, Just Chatting, Fall Guys: Ultimate...
# 18            15766  [Counter-Strike, Just Chatting, Among Us, Spor...
# 19            40631                      [Valorant, Teamfight Tactics]

# %%
df.to_csv("peak_view_streamers.csv", index = False)
