# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
twitch = pd.read_csv("peak_view_streamers.csv")
twitch
# Out:
#     Rank Platform        Channel Name Region   Followers Peak Viewers  \
# 0      1   Twitch                ibai     ES  15,288,314    3,442,745
# 1      2  Nimo TV      NIMO GALA 2023     VI      52,009    3,043,120
# 2      3   Twitch            TheGrefg     ES  11,684,700    2,470,347
# 3      4  Nimo TV              MPL ID     ID   1,421,167    1,503,628
# 4      5   Twitch            Squeezie     FR   4,832,764    1,340,960
# 5      6   Twitch             elxokas     ES   3,632,399    1,208,144
# 6      7   Twitch          aminematue     FR   2,369,866    1,155,060
# 7      8   Twitch          ELEAGUE TV     EN   1,602,862    1,130,760
# 8      9   Twitch         kingsleague     ES   2,999,251    1,108,295
# 9     10   Twitch         PlayStation     EN     867,020    1,016,962
# 10    11   Twitch          Riot Games     EN   6,778,805      990,201
# 11    12  Nimo TV          MixiGaming     VI   2,331,509      984,808
# ...

# %% [markdown]
# # Data Visualization
